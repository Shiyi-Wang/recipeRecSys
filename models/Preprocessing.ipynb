# %% [markdown]
# # Dataset Preparation
# Author: Shiyi Wang

# %%
import pandas as pd
import numpy as np
from collections import Counter

# %% [markdown]
# Load two datasets

# %%
interactions = pd.read_csv('../data/interactions.csv')
recipes = pd.read_csv('../data/recipes.csv')

# %% [markdown]
# Merge two datasets

# %%
recipes = recipes.rename(columns={"id": "recipe_id"})
data = interactions.join(recipes.set_index('recipe_id'), on='recipe_id')

# %% [markdown]
# Add review count column

# %%
def setReviewCountCol(series, name):
    counts = dict(Counter(series))
    return pd.DataFrame.from_dict(counts, orient='index').reset_index().rename(columns={'index': name, 0: f'{name}_count'})

# %%
recipe_id_count = setReviewCountCol(interactions.recipe_id,'recipe_id')

# %% [markdown]
# Merge with dataset

# %%
data = data.merge(recipe_id_count, how='left',
                        left_on='recipe_id', right_on='recipe_id')
data
# Out:
#             user_id  recipe_id        date  rating  \
# 0             38094      40893  2003-02-17       4
# 1           1293707      40893  2011-12-21       5
# 2              8937      44394  2002-12-01       4
# 3            126440      85009  2010-02-27       5
# 4             57222      85009  2011-10-01       5
# ...             ...        ...         ...     ...
# 1132362      116593      72730  2003-12-09       0
# 1132363      583662     386618  2009-09-29       5
# 1132364      157126      78003  2008-06-23       5
# 1132365       53932      78003  2009-01-11       4
# 1132366  2001868099      78003  2017-12-18       5
#
#                                                     review  \
# 0        Great with a salad. Cooked on top of stove for...
# 1        So simple, so delicious! Great for chilly fall...
# 2        This worked very well and is EASY.  I used not...
# 3        I made the Mexican topping and took it to bunk...
# 4        Made the cheddar bacon topping, adding a sprin...
# ...                                                    ...
# 1132362  Another approach is to start making sauce with...
# 1132363  These were so delicious!  My husband and I tru...
# 1132364  WOW!  Sometimes I don't take the time to rate ...
# 1132365  Very good!  I used regular port as well.  The ...
# 1132366  I am so glad I googled and found this here. Th...
#
#                                          name  minutes  contributor_id  \
# 0        white bean   green chile pepper soup      495            1533
# 1        white bean   green chile pepper soup      495            1533
# 2            devilicious cookie cake delights       20           56824
# 3                       baked potato toppings       10           64342
# 4                       baked potato toppings       10           64342
# ...                                       ...      ...             ...
# 1132362          cranberry peach maple relish       22          103078
# 1132363       stacey e s yummy veggie burgers       21          742029
# 1132364        pot roast with port  stove top      115          108291
# 1132365        pot roast with port  stove top      115          108291
# 1132366        pot roast with port  stove top      115          108291
#
#           submitted                                               tags  \
# 0        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 2        2002-10-27  ['30-minutes-or-less', 'time-to-make', 'course...
# 3        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 4        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# ...             ...                                                ...
# 1132362  2003-10-06  ['30-minutes-or-less', 'time-to-make', 'course...
# 1132363  2009-08-24  ['30-minutes-or-less', 'time-to-make', 'course...
# 1132364  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132365  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132366  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
#
#                                                  nutrition  n_steps  \
# 0                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 1                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 2                 [132.3, 11.0, 39.0, 5.0, 4.0, 11.0, 5.0]        5
# 3        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 4        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# ...                                                    ...      ...
# 1132362       [1941.7, 3.0, 1569.0, 3.0, 10.0, 1.0, 154.0]        6
# 1132363           [124.7, 1.0, 11.0, 24.0, 10.0, 0.0, 8.0]        9
# 1132364        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132365        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132366        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
#
#                                                      steps  \
# 0        ['combine beans , onion , chilies , 1 / 2 teas...
# 1        ['combine beans , onion , chilies , 1 / 2 teas...
# 2        ['blend together cake mix , oil and eggs', 'ad...
# 3        ['pick whichever topping you want to use and c...
# 4        ['pick whichever topping you want to use and c...
# ...                                                    ...
# 1132362  ['blend peaches until coarse', 'place in sauce...
# 1132363  ['microwave carrot slices in 1 / 4 inch water ...
# 1132364  ['in a large pan , heat oil and brown roast on...
# 1132365  ['in a large pan , heat oil and brown roast on...
# 1132366  ['in a large pan , heat oil and brown roast on...
#
#                                                description  \
# 0                              easy soup for the crockpot.
# 1                              easy soup for the crockpot.
# 2                                                      NaN
# 3        these toppings sure makes a nice change from p...
# 4        these toppings sure makes a nice change from p...
# ...                                                    ...
# 1132362  great simple alternative to regular cranberry ...
# 1132363  my friend stacey significantly modified a reci...
# 1132364  this is a recipe from the frugal gourmet cooki...
# 1132365  this is a recipe from the frugal gourmet cooki...
# 1132366  this is a recipe from the frugal gourmet cooki...
#
#                                                ingredients  n_ingredients  \
# 0        ['great northern beans', 'yellow onion', 'dice...              9
# 1        ['great northern beans', 'yellow onion', 'dice...              9
# 2        ["devil's food cake mix", 'vegetable oil', 'eg...              4
# 3        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 4        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# ...                                                    ...            ...
# 1132362  ['peaches', 'brown sugar', 'allspice', 'maple ...              6
# 1132363  ['carrot', 'garbanzo beans', 'salsa', 'corn fl...              8
# 1132364  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132365  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132366  ['boneless beef chuck roast', 'olive oil', 'ta...             10
#
#          recipe_id_count
# 0                      2
# 1                      2
# 2                      1
# 3                      2
# 4                      2
# ...                  ...
# 1132362                1
# 1132363                1
# 1132364                4
# 1132365                4
# 1132366                4
#
# [1132367 rows x 17 columns]

# %% [markdown]
# Remove those with only one review

# %%
data_filtered = data[data['recipe_id_count'] > 1]
data_filtered
# Out:
#             user_id  recipe_id        date  rating  \
# 0             38094      40893  2003-02-17       4
# 1           1293707      40893  2011-12-21       5
# 3            126440      85009  2010-02-27       5
# 4             57222      85009  2011-10-01       5
# 5             52282     120345  2005-05-21       4
# ...             ...        ...         ...     ...
# 1132360  2002357020      82303  2018-12-05       5
# 1132361      102526      54493  2007-04-26       0
# 1132364      157126      78003  2008-06-23       5
# 1132365       53932      78003  2009-01-11       4
# 1132366  2001868099      78003  2017-12-18       5
#
#                                                     review  \
# 0        Great with a salad. Cooked on top of stove for...
# 1        So simple, so delicious! Great for chilly fall...
# 3        I made the Mexican topping and took it to bunk...
# 4        Made the cheddar bacon topping, adding a sprin...
# 5        very very sweet. after i waited the 2 days i b...
# ...                                                    ...
# 1132360  Delicious quick thick chocolate sauce with ing...
# 1132361  I am not going to rate this because I did have...
# 1132364  WOW!  Sometimes I don't take the time to rate ...
# 1132365  Very good!  I used regular port as well.  The ...
# 1132366  I am so glad I googled and found this here. Th...
#
#                                          name  minutes  contributor_id  \
# 0        white bean   green chile pepper soup      495            1533
# 1        white bean   green chile pepper soup      495            1533
# 3                       baked potato toppings       10           64342
# 4                       baked potato toppings       10           64342
# 5                         sugared raspberries       10           37449
# ...                                       ...      ...             ...
# 1132360      easy microwave hot fudge topping       10          106436
# 1132361                  garlic clove chicken       65           49304
# 1132364        pot roast with port  stove top      115          108291
# 1132365        pot roast with port  stove top      115          108291
# 1132366        pot roast with port  stove top      115          108291
#
#           submitted                                               tags  \
# 0        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 3        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 4        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 5        2005-05-02  ['15-minutes-or-less', 'time-to-make', 'course...
# ...             ...                                                ...
# 1132360  2004-01-28  ['15-minutes-or-less', 'time-to-make', 'course...
# 1132361  2003-02-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1132364  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132365  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132366  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
#
#                                                  nutrition  n_steps  \
# 0                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 1                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 3        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 4        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 5                 [838.0, 1.0, 820.0, 0.0, 2.0, 0.0, 71.0]        6
# ...                                                    ...      ...
# 1132360          [177.1, 9.0, 100.0, 3.0, 1.0, 18.0, 10.0]        7
# 1132361           [338.3, 32.0, 1.0, 7.0, 53.0, 29.0, 2.0]       10
# 1132364        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132365        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132366        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
#
#                                                      steps  \
# 0        ['combine beans , onion , chilies , 1 / 2 teas...
# 1        ['combine beans , onion , chilies , 1 / 2 teas...
# 3        ['pick whichever topping you want to use and c...
# 4        ['pick whichever topping you want to use and c...
# 5        ['carefully pick over the berries , removing l...
# ...                                                    ...
# 1132360  ['mix dry ingredients', 'stir in room temperat...
# 1132361  ['preheat oven to 325 degrees', 'spray a large...
# 1132364  ['in a large pan , heat oil and brown roast on...
# 1132365  ['in a large pan , heat oil and brown roast on...
# 1132366  ['in a large pan , heat oil and brown roast on...
#
#                                                description  \
# 0                              easy soup for the crockpot.
# 1                              easy soup for the crockpot.
# 3        these toppings sure makes a nice change from p...
# 4        these toppings sure makes a nice change from p...
# 5        here's an old method for preserving fruit with...
# ...                                                    ...
# 1132360  this is an easy and delicious way to get a cho...
# 1132361  garlic and chicken what could be better, the c...
# 1132364  this is a recipe from the frugal gourmet cooki...
# 1132365  this is a recipe from the frugal gourmet cooki...
# 1132366  this is a recipe from the frugal gourmet cooki...
#
#                                                ingredients  n_ingredients  \
# 0        ['great northern beans', 'yellow onion', 'dice...              9
# 1        ['great northern beans', 'yellow onion', 'dice...              9
# 3        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 4        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 5                      ['raspberries', 'granulated sugar']              2
# ...                                                    ...            ...
# 1132360  ['sugar', 'cocoa', 'cornstarch', 'salt', 'wate...              7
# 1132361  ['chicken', 'garlic', 'dry white wine', 'lemon...              6
# 1132364  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132365  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132366  ['boneless beef chuck roast', 'olive oil', 'ta...             10
#
#          recipe_id_count
# 0                      2
# 1                      2
# 3                      2
# 4                      2
# 5                      3
# ...                  ...
# 1132360               19
# 1132361                2
# 1132364                4
# 1132365                4
# 1132366                4
#
# [1040414 rows x 17 columns]

# %% [markdown]
# Clean up by dropping `recipe_id_count` column

# %%
data_cleaned = data_filtered.drop(['recipe_id_count'], axis=1)
data_cleaned
# Out:
#             user_id  recipe_id        date  rating  \
# 0             38094      40893  2003-02-17       4
# 1           1293707      40893  2011-12-21       5
# 3            126440      85009  2010-02-27       5
# 4             57222      85009  2011-10-01       5
# 5             52282     120345  2005-05-21       4
# ...             ...        ...         ...     ...
# 1132360  2002357020      82303  2018-12-05       5
# 1132361      102526      54493  2007-04-26       0
# 1132364      157126      78003  2008-06-23       5
# 1132365       53932      78003  2009-01-11       4
# 1132366  2001868099      78003  2017-12-18       5
#
#                                                     review  \
# 0        Great with a salad. Cooked on top of stove for...
# 1        So simple, so delicious! Great for chilly fall...
# 3        I made the Mexican topping and took it to bunk...
# 4        Made the cheddar bacon topping, adding a sprin...
# 5        very very sweet. after i waited the 2 days i b...
# ...                                                    ...
# 1132360  Delicious quick thick chocolate sauce with ing...
# 1132361  I am not going to rate this because I did have...
# 1132364  WOW!  Sometimes I don't take the time to rate ...
# 1132365  Very good!  I used regular port as well.  The ...
# 1132366  I am so glad I googled and found this here. Th...
#
#                                          name  minutes  contributor_id  \
# 0        white bean   green chile pepper soup      495            1533
# 1        white bean   green chile pepper soup      495            1533
# 3                       baked potato toppings       10           64342
# 4                       baked potato toppings       10           64342
# 5                         sugared raspberries       10           37449
# ...                                       ...      ...             ...
# 1132360      easy microwave hot fudge topping       10          106436
# 1132361                  garlic clove chicken       65           49304
# 1132364        pot roast with port  stove top      115          108291
# 1132365        pot roast with port  stove top      115          108291
# 1132366        pot roast with port  stove top      115          108291
#
#           submitted                                               tags  \
# 0        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 3        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 4        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 5        2005-05-02  ['15-minutes-or-less', 'time-to-make', 'course...
# ...             ...                                                ...
# 1132360  2004-01-28  ['15-minutes-or-less', 'time-to-make', 'course...
# 1132361  2003-02-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1132364  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132365  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132366  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
#
#                                                  nutrition  n_steps  \
# 0                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 1                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 3        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 4        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 5                 [838.0, 1.0, 820.0, 0.0, 2.0, 0.0, 71.0]        6
# ...                                                    ...      ...
# 1132360          [177.1, 9.0, 100.0, 3.0, 1.0, 18.0, 10.0]        7
# 1132361           [338.3, 32.0, 1.0, 7.0, 53.0, 29.0, 2.0]       10
# 1132364        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132365        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132366        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
#
#                                                      steps  \
# 0        ['combine beans , onion , chilies , 1 / 2 teas...
# 1        ['combine beans , onion , chilies , 1 / 2 teas...
# 3        ['pick whichever topping you want to use and c...
# 4        ['pick whichever topping you want to use and c...
# 5        ['carefully pick over the berries , removing l...
# ...                                                    ...
# 1132360  ['mix dry ingredients', 'stir in room temperat...
# 1132361  ['preheat oven to 325 degrees', 'spray a large...
# 1132364  ['in a large pan , heat oil and brown roast on...
# 1132365  ['in a large pan , heat oil and brown roast on...
# 1132366  ['in a large pan , heat oil and brown roast on...
#
#                                                description  \
# 0                              easy soup for the crockpot.
# 1                              easy soup for the crockpot.
# 3        these toppings sure makes a nice change from p...
# 4        these toppings sure makes a nice change from p...
# 5        here's an old method for preserving fruit with...
# ...                                                    ...
# 1132360  this is an easy and delicious way to get a cho...
# 1132361  garlic and chicken what could be better, the c...
# 1132364  this is a recipe from the frugal gourmet cooki...
# 1132365  this is a recipe from the frugal gourmet cooki...
# 1132366  this is a recipe from the frugal gourmet cooki...
#
#                                                ingredients  n_ingredients
# 0        ['great northern beans', 'yellow onion', 'dice...              9
# 1        ['great northern beans', 'yellow onion', 'dice...              9
# 3        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 4        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 5                      ['raspberries', 'granulated sugar']              2
# ...                                                    ...            ...
# 1132360  ['sugar', 'cocoa', 'cornstarch', 'salt', 'wate...              7
# 1132361  ['chicken', 'garlic', 'dry white wine', 'lemon...              6
# 1132364  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132365  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132366  ['boneless beef chuck roast', 'olive oil', 'ta...             10
#
# [1040414 rows x 16 columns]

# %% [markdown]
# Reserialize Recipe and User IDs

# %%
def reserialize(values):
    unique_values = np.unique(values)
    return dict([(x, y) for y, x in enumerate(unique_values)])

# %%
reserialized_User_ID = reserialize(data_cleaned.user_id)
reserialized_Recipe_ID = reserialize(data_cleaned.recipe_id)

# %%
user_ID_converted_dataframe = pd.DataFrame.from_dict(reserialized_User_ID, orient='index').reset_index(
).rename(columns={'index': 'user_id', 0: 'new_user_id'})
recipe_ID_converted_dataframe = pd.DataFrame.from_dict(reserialized_Recipe_ID, orient='index').reset_index(
).rename(columns={'index': 'recipe_id', 0: 'new_recipe_id'})

# %% [markdown]
# Integrate new serialization into dataset

# %%
data_reserialized = data_cleaned.join(user_ID_converted_dataframe.set_index('user_id'), on='user_id')
data_reserialized = data_reserialized .join(recipe_ID_converted_dataframe.set_index('recipe_id'), on='recipe_id')
data_reserialized
# Out:
#             user_id  recipe_id        date  rating  \
# 0             38094      40893  2003-02-17       4
# 1           1293707      40893  2011-12-21       5
# 3            126440      85009  2010-02-27       5
# 4             57222      85009  2011-10-01       5
# 5             52282     120345  2005-05-21       4
# ...             ...        ...         ...     ...
# 1132360  2002357020      82303  2018-12-05       5
# 1132361      102526      54493  2007-04-26       0
# 1132364      157126      78003  2008-06-23       5
# 1132365       53932      78003  2009-01-11       4
# 1132366  2001868099      78003  2017-12-18       5
#
#                                                     review  \
# 0        Great with a salad. Cooked on top of stove for...
# 1        So simple, so delicious! Great for chilly fall...
# 3        I made the Mexican topping and took it to bunk...
# 4        Made the cheddar bacon topping, adding a sprin...
# 5        very very sweet. after i waited the 2 days i b...
# ...                                                    ...
# 1132360  Delicious quick thick chocolate sauce with ing...
# 1132361  I am not going to rate this because I did have...
# 1132364  WOW!  Sometimes I don't take the time to rate ...
# 1132365  Very good!  I used regular port as well.  The ...
# 1132366  I am so glad I googled and found this here. Th...
#
#                                          name  minutes  contributor_id  \
# 0        white bean   green chile pepper soup      495            1533
# 1        white bean   green chile pepper soup      495            1533
# 3                       baked potato toppings       10           64342
# 4                       baked potato toppings       10           64342
# 5                         sugared raspberries       10           37449
# ...                                       ...      ...             ...
# 1132360      easy microwave hot fudge topping       10          106436
# 1132361                  garlic clove chicken       65           49304
# 1132364        pot roast with port  stove top      115          108291
# 1132365        pot roast with port  stove top      115          108291
# 1132366        pot roast with port  stove top      115          108291
#
#           submitted                                               tags  \
# 0        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1        2002-09-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 3        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 4        2004-02-25  ['15-minutes-or-less', 'time-to-make', 'course...
# 5        2005-05-02  ['15-minutes-or-less', 'time-to-make', 'course...
# ...             ...                                                ...
# 1132360  2004-01-28  ['15-minutes-or-less', 'time-to-make', 'course...
# 1132361  2003-02-21  ['weeknight', 'time-to-make', 'course', 'main-...
# 1132364  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132365  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
# 1132366  2003-12-05  ['weeknight', 'time-to-make', 'course', 'prepa...
#
#                                                  nutrition  n_steps  \
# 0                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 1                 [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 3        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 4        [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 5                 [838.0, 1.0, 820.0, 0.0, 2.0, 0.0, 71.0]        6
# ...                                                    ...      ...
# 1132360          [177.1, 9.0, 100.0, 3.0, 1.0, 18.0, 10.0]        7
# 1132361           [338.3, 32.0, 1.0, 7.0, 53.0, 29.0, 2.0]       10
# 1132364        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132365        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
# 1132366        [828.2, 87.0, 22.0, 20.0, 93.0, 112.0, 4.0]        8
#
#                                                      steps  \
# 0        ['combine beans , onion , chilies , 1 / 2 teas...
# 1        ['combine beans , onion , chilies , 1 / 2 teas...
# 3        ['pick whichever topping you want to use and c...
# 4        ['pick whichever topping you want to use and c...
# 5        ['carefully pick over the berries , removing l...
# ...                                                    ...
# 1132360  ['mix dry ingredients', 'stir in room temperat...
# 1132361  ['preheat oven to 325 degrees', 'spray a large...
# 1132364  ['in a large pan , heat oil and brown roast on...
# 1132365  ['in a large pan , heat oil and brown roast on...
# 1132366  ['in a large pan , heat oil and brown roast on...
#
#                                                description  \
# 0                              easy soup for the crockpot.
# 1                              easy soup for the crockpot.
# 3        these toppings sure makes a nice change from p...
# 4        these toppings sure makes a nice change from p...
# 5        here's an old method for preserving fruit with...
# ...                                                    ...
# 1132360  this is an easy and delicious way to get a cho...
# 1132361  garlic and chicken what could be better, the c...
# 1132364  this is a recipe from the frugal gourmet cooki...
# 1132365  this is a recipe from the frugal gourmet cooki...
# 1132366  this is a recipe from the frugal gourmet cooki...
#
#                                                ingredients  n_ingredients  \
# 0        ['great northern beans', 'yellow onion', 'dice...              9
# 1        ['great northern beans', 'yellow onion', 'dice...              9
# 3        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 4        ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 5                      ['raspberries', 'granulated sugar']              2
# ...                                                    ...            ...
# 1132360  ['sugar', 'cocoa', 'cornstarch', 'salt', 'wate...              7
# 1132361  ['chicken', 'garlic', 'dry white wine', 'lemon...              6
# 1132364  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132365  ['boneless beef chuck roast', 'olive oil', 'ta...             10
# 1132366  ['boneless beef chuck roast', 'olive oil', 'ta...             10
#
#          new_user_id  new_recipe_id
# 0               3787          16642
# 1              95286          16642
# 3              14502          34897
# 4               6559          34897
# 5               5690          49598
# ...              ...            ...
# 1132360       215681          33795
# 1132361        11621          22415
# 1132364        17831          32160
# 1132365         5947          32160
# 1132366       202858          32160
#
# [1040414 rows x 18 columns]

# %% [markdown]
# Finalize dataset by keeping the new IDs and removing the old ones.

# %%
data_finalized = data_reserialized.drop(['user_id', 'recipe_id'], axis= 1)
data_finalized = data_finalized.rename(columns={"new_user_id": "user_id", "new_recipe_id": "recipe_id"})

# %% [markdown]
# Finalized dataset

# %%
data_finalized.sort_values(by=["recipe_id"])
# Out:
#               date  rating                                             review  \
# 110594  2009-01-15       4  very good!! the directions were alittle weird ...
# 110595  2014-07-22       4  This does taste great! I think the recipe need...
# 110596  2014-08-14       4  Tasty and refreshing! I love the creamy flavor...
# 110593  2008-02-13       5  Yummy, yummy, yummy! I am a big fan of fruit a...
# 634159  2007-07-20       5  My parents went like wow when they dranked it! :)
# ...            ...     ...                                                ...
# 524809  2018-10-10       5  I was a little surprised to see the previous r...
# 771231  2018-09-11       0  What is cauliflower rice ? Is it a califlower ...
# 771232  2018-10-22       0                 What do you do with the olive oil?
# 119482  2018-12-03       0  I thought this came out pretty good, nice fres...
# 119483  2018-12-04       4  Was tasty, hubby and daughter loved it, will p...
#
#                                                      name  minutes  \
# 110594                  low fat berry blue frozen dessert     1485
# 110595                  low fat berry blue frozen dessert     1485
# 110596                  low fat berry blue frozen dessert     1485
# 110593                  low fat berry blue frozen dessert     1485
# 634159                                      best lemonade       35
# ...                                                   ...      ...
# 524809  sheet pan turkey caprese meatballs with rosema...       50
# 771231                            sheet pan shrimp scampi       30
# 771232                            sheet pan shrimp scampi       30
# 119482  baked shrimp and orzo with chickpeas  lemon  a...       15
# 119483  baked shrimp and orzo with chickpeas  lemon  a...       15
#
#         contributor_id   submitted  \
# 110594            1533  1999-08-09
# 110595            1533  1999-08-09
# 110596            1533  1999-08-09
# 110593            1533  1999-08-09
# 634159            1566  1999-09-05
# ...                ...         ...
# 524809      2001112113  2018-08-31
# 771231      2001112113  2018-08-31
# 771232      2001112113  2018-08-31
# 119482      2002285039  2018-10-02
# 119483      2002285039  2018-10-02
#
#                                                      tags  \
# 110594  ['weeknight', 'time-to-make', 'course', 'prepa...
# 110595  ['weeknight', 'time-to-make', 'course', 'prepa...
# 110596  ['weeknight', 'time-to-make', 'course', 'prepa...
# 110593  ['weeknight', 'time-to-make', 'course', 'prepa...
# 634159  ['60-minutes-or-less', 'time-to-make', 'course...
# ...                                                   ...
# 524809  ['60-minutes-or-less', 'time-to-make', 'course...
# 771231  ['30-minutes-or-less', 'time-to-make', 'course...
# 771232  ['30-minutes-or-less', 'time-to-make', 'course...
# 119482  ['15-minutes-or-less', 'time-to-make', 'main-i...
# 119483  ['15-minutes-or-less', 'time-to-make', 'main-i...
#
#                                           nutrition  n_steps  \
# 110594     [170.9, 3.0, 120.0, 1.0, 6.0, 6.0, 12.0]       13
# 110595     [170.9, 3.0, 120.0, 1.0, 6.0, 6.0, 12.0]       13
# 110596     [170.9, 3.0, 120.0, 1.0, 6.0, 6.0, 12.0]       13
# 110593     [170.9, 3.0, 120.0, 1.0, 6.0, 6.0, 12.0]       13
# 634159     [311.1, 0.0, 308.0, 0.0, 0.0, 0.0, 27.0]        8
# ...                                             ...      ...
# 524809  [541.6, 44.0, 14.0, 43.0, 74.0, 45.0, 11.0]       14
# 771231   [728.9, 43.0, 2.0, 69.0, 78.0, 64.0, 25.0]       14
# 771232   [728.9, 43.0, 2.0, 69.0, 78.0, 64.0, 25.0]       14
# 119482  [735.9, 39.0, 22.0, 71.0, 75.0, 40.0, 27.0]       18
# 119483  [735.9, 39.0, 22.0, 71.0, 75.0, 40.0, 27.0]       18
#
#                                                     steps  \
# 110594  ['toss 2 cups berries with sugar', 'let stand ...
# 110595  ['toss 2 cups berries with sugar', 'let stand ...
# 110596  ['toss 2 cups berries with sugar', 'let stand ...
# 110593  ['toss 2 cups berries with sugar', 'let stand ...
# 634159  ['into a 1 quart jar with tight fitting lid , ...
# ...                                                   ...
# 524809  ['preheat oven to 400 degrees f', 'line a baki...
# 771231  ['preheat oven to 450 degrees f', 'line a baki...
# 771232  ['preheat oven to 450 degrees f', 'line a baki...
# 119482  ['preheat oven to 450 degrees', 'dry shrimp wi...
# 119483  ['preheat oven to 450 degrees', 'dry shrimp wi...
#
#                                               description  \
# 110594  this is yummy and low-fat, it always turns out...
# 110595  this is yummy and low-fat, it always turns out...
# 110596  this is yummy and low-fat, it always turns out...
# 110593  this is yummy and low-fat, it always turns out...
# 634159  this is from one of my  first good house keepi...
# ...                                                   ...
# 524809  description: try these turkey caprese meatball...
# 771231  a super quick, yet super delicious sheet pan s...
# 771232  a super quick, yet super delicious sheet pan s...
# 119482  shrimp and orzo make for a simple and flavorfu...
# 119483  shrimp and orzo make for a simple and flavorfu...
#
#                                               ingredients  n_ingredients  \
# 110594  ['blueberries', 'granulated sugar', 'vanilla y...              4
# 110595  ['blueberries', 'granulated sugar', 'vanilla y...              4
# 110596  ['blueberries', 'granulated sugar', 'vanilla y...              4
# 110593  ['blueberries', 'granulated sugar', 'vanilla y...              4
# 634159  ['sugar', 'lemons, rind of', 'fresh water', 'f...              6
# ...                                                   ...            ...
# 524809  ['ground turkey', 'egg', 'italian seasoning', ...             15
# 771231  ['unsalted butter', 'olive oil', 'salt', 'crus...             12
# 771232  ['unsalted butter', 'olive oil', 'salt', 'crus...             12
# 119482  ['jumbo shrimp', 'salt & freshly ground black ...             15
# 119483  ['jumbo shrimp', 'salt & freshly ground black ...             15
#
#         user_id  recipe_id
# 110594    84409          0
# 110595   158411          0
# 110596   126961          0
# 110593    57566          0
# 634159    53641          1
# ...         ...        ...
# 524809   214596     139681
# 771231   207893     139682
# 771232   207339     139682
# 119482   213239     139683
# 119483   211320     139683
#
# [1040414 rows x 16 columns]

# %% [markdown]
# Save as Pickle file

# %%
data_finalized.to_pickle("../data/processed_data.pkl")
print("Pickle file saved successfully")
# Out:
# Pickle file saved successfully

# %% [markdown]
# A data process for the random generation of "Ingredients I might want to have" functionality used in a frontend button.

# %% [markdown]
# Generate a list of top 1000 popular ingredients in json file among 6714 ingredients from a total of 39774 recipes.

# %% [markdown]
# Most popular ingredient is on the top.

# %% [markdown]
# Original dataset: https://www.kaggle.com/datasets/kaggle/recipe-ingredients-dataset?resource=download&select=train.json

# %%
import json
'''
Generate top 1000 popular ingredients in a total of 6714 ingredients 
from 39774 recipes. Most popular ingredient is on the top.
'''

with open('../data/ingredients.json') as f:
    data = json.load(f)

ingredients = {}
for item in data:
    for i in item['ingredients']:
        if i not in ingredients:
            ingredients[str(i)] = 1
        else:
            ingredients[str(i)] += 1

sorted_ingredients_in_frequency = sorted(
    ingredients, key=ingredients.get, reverse=True)
random_generate_ingredients_range = sorted_ingredients_in_frequency[:1000]

# only change generating to true if you want to regenerate the data
# data is already generated. Please do not regenerate when re-run.
generating = False
if generating:
    with open('../data/top_ingredients.json', 'w') as f:
        json.dump(random_generate_ingredients_range, f, indent=2)

# %% [markdown]
# The top 1000 ingredients is stored in "../data/top_ingredients.json"
